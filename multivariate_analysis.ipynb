# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
dataset = pd.read_csv("multivariate_dataset.csv")
dataset
# Out:
#            NIM  JenisKelamin(L=1, P=0)  Usia(hari)  PSQI1  PSQI2  PSQI3  \
# 0   1902511093                       0        7849      0      3      1
# 1   1902511038                       1        7984      0      3      2
# 2   1902511030                       0        7928      0      0      1
# 3   1902511190                       0        7792      0      2      2
# 4   1902511019                       1        7819      0      0      1
# ..         ...                     ...         ...    ...    ...    ...
# 70  1902511045                       1        7911      0      2      1
# 71  1902511047                       1        7838      2      0      3
# 72  1902511218                       0        7939      0      1      0
# 73  1902511003                       0        7722      0      0      1
# 74  1902511102                       0        7783      0      1      2
#
#     PSQI4  PSQI5  PSQI6  PSQI7  Skor_PSQI  Skor_Backspan
# 0       6      0      1      1         12              3
# 1      12      0      2      1         20              3
# 2       9      0      1      1         12              0
# 3       4      0      1      1         10              2
# 4       6      0      1      1          9              5
# ..    ...    ...    ...    ...        ...            ...
# 70      4      2      1      1         11              5
# 71      0      0      0      1          6              5
# 72      6      0      0      1          8              3
# 73      5      0      1      1          8              3
# 74      5      0      1      1         10              3
#
# [75 rows x 12 columns]

# %%
x = dataset.iloc[:, [1, 2, 3, 4, 5, 6, 7, 8, 9]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
#   Input In [17]
#     x = dataset.iloc[:, [1:-2]].values
#                           ^
# SyntaxError: invalid syntax

# %%
regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     6.217
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):           0.000825
# Time:                        19:01:45   Log-Likelihood:                -140.05
# No. Observations:                  75   AIC:                             288.1
# Df Residuals:                      71   BIC:                             297.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.8184      8.800      1.343      0.184      -5.728      29.364
# x1             0.2840      0.390      0.729      0.468      -0.493       1.061
# x2            -0.0008      0.001     -0.746      0.458      -0.003       0.001
# x3            -0.1650      0.044     -3.789      0.000      -0.252      -0.078
# ==============================================================================
# Omnibus:                        0.216   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.898   Jarque-Bera (JB):                0.406
# Skew:                          -0.042   Prob(JB):                        0.816
# Kurtosis:                       2.649   Cond. No.                     3.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = dataset.iloc[:, [2, -2]].values
y = dataset.iloc[:, -1].values
x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     9.118
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):           0.000295
# Time:                        19:03:07   Log-Likelihood:                -140.33
# No. Observations:                  75   AIC:                             286.7
# Df Residuals:                      72   BIC:                             293.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.8644      8.771      1.353      0.180      -5.620      29.348
# x1            -0.0008      0.001     -0.739      0.462      -0.003       0.001
# x2            -0.1685      0.043     -3.904      0.000      -0.254      -0.082
# ==============================================================================
# Omnibus:                        0.524   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.769   Jarque-Bera (JB):                0.657
# Skew:                          -0.074   Prob(JB):                        0.720
# Kurtosis:                       2.566   Cond. No.                     3.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = dataset.iloc[:, [-2]].values
y = dataset.iloc[:, -1].values
x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     17.80
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):           6.95e-05
# Time:                        19:03:41   Log-Likelihood:                -140.61
# No. Observations:                  75   AIC:                             285.2
# Df Residuals:                      73   BIC:                             289.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.3931      0.432     12.493      0.000       4.533       6.253
# x1            -0.1762      0.042     -4.219      0.000      -0.259      -0.093
# ==============================================================================
# Omnibus:                        0.719   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.698   Jarque-Bera (JB):                0.789
# Skew:                          -0.083   Prob(JB):                        0.674
# Kurtosis:                       2.526   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Detail PSQI aspect

# %%
x = dataset.iloc[:, [1, 2, 3, 4, 5, 6, 7, 8, 9]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     2.474
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):             0.0171
# Time:                        11:36:43   Log-Likelihood:                -137.75
# No. Observations:                  75   AIC:                             295.5
# Df Residuals:                      65   BIC:                             318.7
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.9055      9.105      1.308      0.196      -6.278      30.089
# x1             0.1761      0.427      0.413      0.681      -0.676       1.028
# x2            -0.0009      0.001     -0.759      0.450      -0.003       0.001
# x3            -0.1247      0.308     -0.404      0.687      -0.741       0.491
# x4            -0.3027      0.231     -1.311      0.194      -0.764       0.158
# x5            -0.0347      0.300     -0.115      0.908      -0.634       0.565
# x6            -0.2351      0.064     -3.662      0.001      -0.363      -0.107
# x7             0.6173      0.645      0.957      0.342      -0.671       1.905
# x8             0.1109      0.304      0.364      0.717      -0.497       0.719
# x9             0.0028      0.425      0.007      0.995      -0.846       0.852
# ==============================================================================
# Omnibus:                        0.048   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.976   Jarque-Bera (JB):                0.200
# Skew:                          -0.040   Prob(JB):                        0.905
# Kurtosis:                       2.760   Cond. No.                     3.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = dataset.iloc[:, [1, 2, 3, 4, 5, 6, 7, 8]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     2.826
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):            0.00928
# Time:                        11:37:54   Log-Likelihood:                -137.75
# No. Observations:                  75   AIC:                             293.5
# Df Residuals:                      66   BIC:                             314.4
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.9092      9.018      1.321      0.191      -6.097      29.915
# x1             0.1756      0.416      0.422      0.674      -0.655       1.006
# x2            -0.0009      0.001     -0.765      0.447      -0.003       0.001
# x3            -0.1252      0.296     -0.423      0.674      -0.716       0.466
# x4            -0.3028      0.229     -1.325      0.190      -0.759       0.154
# x5            -0.0337      0.264     -0.128      0.899      -0.561       0.494
# x6            -0.2350      0.064     -3.695      0.000      -0.362      -0.108
# x7             0.6175      0.639      0.967      0.337      -0.658       1.893
# x8             0.1115      0.292      0.382      0.703      -0.471       0.694
# ==============================================================================
# Omnibus:                        0.048   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.976   Jarque-Bera (JB):                0.200
# Skew:                          -0.040   Prob(JB):                        0.905
# Kurtosis:                       2.760   Cond. No.                     3.79e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = dataset.iloc[:, [1, 2, 3, 4, 6, 7, 8]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     3.276
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):            0.00471
# Time:                        11:37:59   Log-Likelihood:                -137.76
# No. Observations:                  75   AIC:                             291.5
# Df Residuals:                      67   BIC:                             310.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.9135      8.952      1.331      0.188      -5.955      29.782
# x1             0.1704      0.411      0.415      0.680      -0.650       0.991
# x2            -0.0009      0.001     -0.775      0.441      -0.003       0.001
# x3            -0.1460      0.246     -0.594      0.554      -0.636       0.344
# x4            -0.3011      0.227     -1.329      0.188      -0.753       0.151
# x5            -0.2349      0.063     -3.721      0.000      -0.361      -0.109
# x6             0.6175      0.634      0.974      0.334      -0.648       1.883
# x7             0.1047      0.285      0.368      0.714      -0.463       0.673
# ==============================================================================
# Omnibus:                        0.034   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.983   Jarque-Bera (JB):                0.161
# Skew:                          -0.043   Prob(JB):                        0.923
# Kurtosis:                       2.790   Cond. No.                     3.79e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = dataset.iloc[:, [1, 2, 3, 4, 6, 7]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.253
# Model:                            OLS   Adj. R-squared:                  0.188
# Method:                 Least Squares   F-statistic:                     3.848
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):            0.00231
# Time:                        11:38:21   Log-Likelihood:                -137.84
# No. Observations:                  75   AIC:                             289.7
# Df Residuals:                      68   BIC:                             305.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.3662      8.771      1.296      0.199      -6.137      28.869
# x1             0.1513      0.405      0.374      0.710      -0.657       0.960
# x2            -0.0008      0.001     -0.723      0.472      -0.003       0.001
# x3            -0.1578      0.242     -0.652      0.516      -0.641       0.325
# x4            -0.2847      0.221     -1.290      0.201      -0.725       0.156
# x5            -0.2292      0.061     -3.768      0.000      -0.351      -0.108
# x6             0.6222      0.630      0.988      0.327      -0.635       1.879
# ==============================================================================
# Omnibus:                        0.045   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.978   Jarque-Bera (JB):                0.187
# Skew:                          -0.044   Prob(JB):                        0.911
# Kurtosis:                       2.771   Cond. No.                     3.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = dataset.iloc[:, [2, 3, 4, 6, 7]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.252
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     4.647
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):            0.00103
# Time:                        11:38:30   Log-Likelihood:                -137.91
# No. Observations:                  75   AIC:                             287.8
# Df Residuals:                      69   BIC:                             301.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.3229      8.716      1.299      0.198      -6.064      28.710
# x1            -0.0008      0.001     -0.715      0.477      -0.003       0.001
# x2            -0.1412      0.236     -0.597      0.552      -0.613       0.330
# x3            -0.2926      0.218     -1.340      0.185      -0.728       0.143
# x4            -0.2330      0.060     -3.909      0.000      -0.352      -0.114
# x5             0.6778      0.608      1.114      0.269      -0.536       1.891
# ==============================================================================
# Omnibus:                        0.114   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.945   Jarque-Bera (JB):                0.283
# Skew:                          -0.062   Prob(JB):                        0.868
# Kurtosis:                       2.726   Cond. No.                     3.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = dataset.iloc[:, [2, 4, 6, 7]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.248
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     5.773
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):           0.000449
# Time:                        11:40:08   Log-Likelihood:                -138.11
# No. Observations:                  75   AIC:                             286.2
# Df Residuals:                      70   BIC:                             297.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.1075      8.668      1.281      0.204      -6.180      28.395
# x1            -0.0008      0.001     -0.699      0.487      -0.003       0.001
# x2            -0.3119      0.215     -1.451      0.151      -0.740       0.117
# x3            -0.2292      0.059     -3.885      0.000      -0.347      -0.112
# x4             0.7187      0.602      1.194      0.236      -0.481       1.919
# ==============================================================================
# Omnibus:                        0.120   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.942   Jarque-Bera (JB):                0.298
# Skew:                          -0.054   Prob(JB):                        0.862
# Kurtosis:                       2.711   Cond. No.                     3.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = dataset.iloc[:, [4, 6, 7]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     7.589
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):           0.000180
# Time:                        11:40:15   Log-Likelihood:                -138.37
# No. Observations:                  75   AIC:                             284.7
# Df Residuals:                      71   BIC:                             294.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.0516      0.350     14.417      0.000       4.353       5.750
# x1            -0.3370      0.211     -1.596      0.115      -0.758       0.084
# x2            -0.2352      0.058     -4.044      0.000      -0.351      -0.119
# x3             0.7308      0.599      1.219      0.227      -0.464       1.926
# ==============================================================================
# Omnibus:                        0.213   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.899   Jarque-Bera (JB):                0.397
# Skew:                          -0.070   Prob(JB):                        0.820
# Kurtosis:                       2.672   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = dataset.iloc[:, [4, 6]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     10.57
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):           9.45e-05
# Time:                        11:40:33   Log-Likelihood:                -139.14
# No. Observations:                  75   AIC:                             284.3
# Df Residuals:                      72   BIC:                             291.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.0021      0.349     14.324      0.000       4.306       5.698
# x1            -0.2945      0.209     -1.410      0.163      -0.711       0.122
# x2            -0.2213      0.057     -3.867      0.000      -0.335      -0.107
# ==============================================================================
# Omnibus:                        0.454   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.797   Jarque-Bera (JB):                0.606
# Skew:                          -0.076   Prob(JB):                        0.739
# Kurtosis:                       2.587   Cond. No.                         11.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = dataset.iloc[:, [6]].values
y = dataset.iloc[:, -1].values

x_opt = np.append(arr = np.ones((len(x),1)).astype(int), values = x, axis = 1)

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit() 
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.195
# Method:                 Least Squares   F-statistic:                     18.90
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):           4.40e-05
# Time:                        11:40:39   Log-Likelihood:                -140.17
# No. Observations:                  75   AIC:                             284.3
# Df Residuals:                      73   BIC:                             289.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7245      0.290     16.273      0.000       4.146       5.303
# x1            -0.2420      0.056     -4.347      0.000      -0.353      -0.131
# ==============================================================================
# Omnibus:                        0.370   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.831   Jarque-Bera (JB):                0.537
# Skew:                           0.114   Prob(JB):                        0.764
# Kurtosis:                       2.654   Cond. No.                         8.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
